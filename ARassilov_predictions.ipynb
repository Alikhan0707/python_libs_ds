# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV

# %% [markdown]
# #  Указываем путь к файлам с данными

# %%
PATH_TO_TRAIN_FILE = 'train.csv'
PATH_TO_TEST_FILE = 'test.csv'

# %% [markdown]
# # Заполняем таблицы pandas данными

# %%
train_df = pd.read_csv(PATH_TO_TRAIN_FILE)
train_df.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
train_df.shape
# Out:
# (10000, 20)

# %%
test_df = pd.read_csv(PATH_TO_TEST_FILE)
test_df.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %%
test_df.shape
# Out:
# (5000, 19)

# %% [markdown]
# # Проверяем таблицы на пропущенные данные

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     3959 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   int64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   int64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   object
#  11  Ecology_3      5000 non-null   object
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int64
#  14  Social_3       5000 non-null   int64
#  15  Healthcare_1   2623 non-null   float64
#  16  Helthcare_2    5000 non-null   int64
# ...

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
test_df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.449500    36.158810
# std     4832.674037    44.179466     0.838594    19.092787    17.825287
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
train_df.nunique()
# Out:
# Id               10000
# DistrictId         205
# Rooms                9
# Square           10000
# LifeSquare        7887
# KitchenSquare       58
# Floor               33
# HouseFloor          44
# HouseYear           97
# Ecology_1          129
# Ecology_2            2
# Ecology_3            2
# Social_1            51
# Social_2           142
# Social_3            30
# Healthcare_1        79
# Helthcare_2          7
# Shops_1             16
# Shops_2              2
# Price            10000
# dtype: int64

# %%
# sns.pairplot(train_df.select_dtypes(include=['float64', 'int64']))

# %% [markdown]
# ## Рисуем графики, чтобы убедится в присутствии выбросов в таблице

# %%
plt.scatter(train_df['Square'], train_df['KitchenSquare'])
plt.show()

# %%
plt.scatter(test_df['Square'], test_df['KitchenSquare'])
plt.show()

# %%
train_df.loc[train_df['HouseYear'] > 2020]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B
#
#               Price
# 1497  254084.534396
# 4189  243028.603096

# %% [markdown]
# # Заполняем пропущенные данные в таблице

# %%
train_df.loc[train_df['HouseYear'] == 20052011, 'HouseYear'] = np.int64(2011)

# %%
train_df.loc[train_df['HouseYear'] == 4968, 'HouseYear'] = np.int64(1968)

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.273300      8.526700     12.609400   1984.866300      0.118858
# ...

# %%
def fill_kitchen_square(df):
    df.loc[df['KitchenSquare'] >= df['Square'], 'KitchenSquare'] = df['KitchenSquare'].median()

# %%
fill_kitchen_square(train_df)
fill_kitchen_square(test_df)

# %%
def fill_life_square(df):
    median_coeff = (train_df['LifeSquare'] / (train_df['Square'] - train_df['KitchenSquare'])).median()
    df.loc[(df['Square'] - 
            df['LifeSquare'] - 
            df['KitchenSquare'] < 0) | 
           (df['LifeSquare'].isna()), 
           'LifeSquare'] = (df['Square'] - df['KitchenSquare']) * median_coeff

# %%
fill_life_square(train_df)
fill_life_square(test_df)

# %%
def house_floor(df):
    df.loc[df['HouseFloor'] < df['Floor'], 'HouseFloor'] = df.loc[df['HouseFloor'] < df['Floor'], 'Floor']

# %%
house_floor(train_df)
house_floor(test_df)

# %%
def room_zero(df):
    df.loc[df['Rooms'] == 0, 'Rooms'] = np.float64(1)

# %%
room_zero(train_df)
room_zero(test_df)

# %% [markdown]
# # Преобразуем в dummy-переменные

# %%
train_df.replace({'Ecology_2': {'A': 0, 'B': 1}, 
                  'Ecology_3': {'A': 0, 'B': 1}, 
                  'Shops_2': {'A': 0, 'B': 1}}, inplace=True)

# %%
train_df.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   32.032935            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040          1          1        33      7976
# 1         9.0       1978   0.000070          1          1        46     10309
# 2        12.0       1968   0.049637          1          1        34      7759
# 3        17.0       1977   0.437885          1          1        23      5735
# 4        12.0       1976   0.012339          1          1        35      5776
#
# ...

# %% [markdown]
# #### Делим таблицу на тренировоный и тестовый датасеты

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df.drop(['Id', 'Healthcare_1', 'Price'], axis='columns'), 
                                                    train_df['Price'], test_size=0.2, random_state=22)

# %% [markdown]
# # Обучаем модель

# %%
rfr = RandomForestRegressor(max_depth=15, n_estimators=250, random_state=42)
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.715424458246086

# %%
rfr.fit(train_df.drop(['Id', 'Healthcare_1', 'Price'], axis='columns'), train_df['Price'])
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=15, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=250, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
test_df.replace({'Ecology_2': {'A': 0, 'B': 1}, 
                  'Ecology_3': {'A': 0, 'B': 1}, 
                  'Shops_2': {'A': 0, 'B': 1}}, inplace=True)
price_pred = rfr.predict(test_df.drop(['Id', 'Healthcare_1'], axis='columns'))

# %% [markdown]
# # Сохраняем результаты в файл .csv

# %%
test_df['Price'] = price_pred

# %%
test_df[['Id', 'Price']].to_csv('ARassilov_prediction.csv', index=False)
